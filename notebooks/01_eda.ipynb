# %% [markdown]
# # NSL-KDD Exploratory Data Analysis
#
# This notebook should include class balance charts, a correlation heatmap, top-variance feature distributions, and a written summary.

# %%
import pandas as pd
from src.preprocessing.loader import load_dataset
from config import RAW_DATA_DIR

# Load data here once KDDTrain+.txt is available.

# %% [markdown]
# ## Summary
#
# The dataset is class-imbalanced, which is why macro/weighted metrics are required.
